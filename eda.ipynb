# %% [markdown]
# # EDA

# %% [markdown]
# ## Split Download
# run `s3_download_fast.sh`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


split_df = pd.read_csv('Split omnibus screen_HG - hits_concat_df.csv')
split_df.head()
# Out:
#   Order: reason? Unnamed: 1     line      class Tony - type     Line  \
# 0            NaN     MB485B   MB485B      mixed     various   MB485B
# 1            NaN    OL0022B  OL0022B  local/asc    ? sparse  OL0022B
# 2            NaN    OL0027B  OL0027B     leg MN           ?  OL0027B
# 3            NaN    SS00313  SS00313      mixed    23B, 20A  SS00313
# 4            NaN    SS00320  SS00320      inter     various  SS00320
#
#   Adult/\nLarval Main annotator    Lab  Quality Sex difference  \
# 0          Adult      Yoshi Aso    Aso        2              N
# 1          Adult  Aljoscha Nern  Rubin        1              N
# 2          Adult  Aljoscha Nern  Rubin        1              N
# 3          Adult  Aljoscha Nern  Rubin        2              N
# 4          Adult  Aljoscha Nern  Rubin        2              N
#
#                     DOI to cite First author(s) & year  Janelia Robot ID  \
# 0     10.1101/2023.09.15.557808            Shuai; 2023         2501827.0
# 1           10.7554/eLife.21022         Wu, Nern; 2016         2135391.0
# 2           10.7554/eLife.21022         Wu, Nern; 2016         2135396.0
# 3  10.1016/j.neuron.2017.03.010         Strother; 2017         2502520.0
# 4           10.7554/eLife.50901      Davis, Nern; 2020         2502527.0
#
#            Cell types                                        EM Body IDs  \
# 0   DL3_lPN, VM4_lvPN  1609542060, 1609883245, 1640568102\n726207450,...
# 1  LC10, LC10a, LC10d                                                NaN
# 2                LC13                                                NaN
# 3                 Tm3                                                NaN
# 4                 Tm4                                                NaN
#
#                                Alias  \
# 0  GMR_48H12_BB_21-x-GMR_37E06_AV_01
# 1  GMR_35D04_XA_21-x-GMR_91B01_XD_01
# 2  GMR_14A11_XA_21-x-GMR_50C10_XD_01
# 3              GMR_38C11-x-GMR_59C10
# 4              GMR_53C02-x-GMR_60H04
#
#                                             Genotype
# 0  w[1118]; P{y[+t7.7] w[+mC]=R48H12-p65.AD}attP4...
# 1  w; 35D04-p65ADZp in attP40; 91B01-ZpGdbd in attP2
# 2  w; 14A11-p65ADZp in attP40/CyO; 50C10-ZpGdbd i...
# 3  w; 38C11-p65ADZp in attP40/CyO; 59C10-ZpGdbd i...
# 4  w; 53C02-p65ADZp in attP40/CyO; 60H04-ZpGdbd i...

# %%
# write files names to filelist.txt for download
for line in split_df['line'].tolist():
    with open('filelist.txt', 'a') as f:
        f.write(line + '\n')
