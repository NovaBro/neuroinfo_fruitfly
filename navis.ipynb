# %%
import navis

# Load a single example neuron
n = navis.example_neurons(n=1, kind='skeleton')
n
# Out:
# Matplotlib is building the font cache; this may take a moment.
# type                                             navis.TreeNeuron
# name                                                    DA1_lPN_R
# id                                                     1734350788
# n_nodes                                                      4465
# n_connectors                                                 2705
# n_branches                                                    599
# n_leafs                                                       618
# cable_length                                           266476.875
# soma                                                         4177
# units                                                 8 nanometer
# created_at                             2026-06-16 13:30:24.007979
# origin          /opt/miniconda3/envs/neurofly/lib/python3.12/s...
# file                                               1734350788.swc
# dtype: object

# %%
n.nodes.head()
# Out:
#    node_id label        x        y        z     radius  parent_id  type
# 0        1     0  15784.0  37250.0  28062.0  10.000000         -1  root
# 1        2     0  15764.0  37230.0  28082.0  18.284300          1  slab
# 2        3     0  15744.0  37190.0  28122.0  34.721401          2  slab
# 3        4     0  15744.0  37150.0  28202.0  34.721401          3  slab
# 4        5     0  15704.0  37130.0  28242.0  34.721401          4  slab

# %%
fig, ax = navis.plot2d(n, view=('x', '-z'), color="coral", method='2d')

# %%
# Ask for 3 example neurons
nl = navis.example_neurons(n=3, kind='skeleton')
nl
# Out:
# <class 'navis.core.neuronlist.NeuronList'> containing 3 neurons (0.0B)
#                type       name          id  n_nodes  n_connectors  n_branches  \
# 0  navis.TreeNeuron  DA1_lPN_R  1734350788     4465          2705         599
# 1  navis.TreeNeuron  DA1_lPN_R  1734350908     4847          3042         735
# 2  navis.TreeNeuron  DA1_lPN_R   722817260     4332          3136         633
#
#    n_leafs  cable_length    soma        units                  created_at  \
# 0      618  266476.87500  4177.0  8 nanometer  2026-06-16 13:31:12.650106
# 1      761  304332.65625     6.0  8 nanometer  2026-06-16 13:31:12.659456
# 2      656  274703.37500     NaN  8 nanometer  2026-06-16 13:31:12.664219
#
#                                               origin            file
# 0  /opt/miniconda3/envs/neurofly/lib/python3.12/s...  1734350788.swc
# 1  /opt/miniconda3/envs/neurofly/lib/python3.12/s...  1734350908.swc
# 2  /opt/miniconda3/envs/neurofly/lib/python3.12/s...   722817260.swc

# %%
# Access the first neuron in the list
nl[0]
# Out:
# type                                             navis.TreeNeuron
# name                                                    DA1_lPN_R
# id                                                     1734350788
# n_nodes                                                      4465
# n_connectors                                                 2705
# n_branches                                                    599
# n_leafs                                                       618
# cable_length                                           266476.875
# soma                                                         4177
# units                                                 8 nanometer
# created_at                             2026-06-16 13:31:12.650106
# origin          /opt/miniconda3/envs/neurofly/lib/python3.12/s...
# file                                               1734350788.swc
# dtype: object

# %%
# Get the cable length for all neurons in the list
nl.cable_length
# Out:
# array([266476.88, 304332.66, 274703.38], dtype=float32)

# %%
# Generate a plot of our neurons
fig, ax = navis.plot2d(nl, view=('x', '-z'), method='2d')

# %% [markdown]
# ## Loading FANC SWC
