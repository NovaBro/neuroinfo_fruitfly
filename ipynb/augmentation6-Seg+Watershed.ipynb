# %% [markdown]
# # Augmentations-4: Results / Tests on Data Part 1 - Aug

# %%
import os
import sys
import time
from pathlib import Path

root = Path.cwd()
print(root)
if root.name == "ipynb":
    root = root.parent
    os.chdir(root)
print(root)

_ipynb = Path.cwd() / "ipynb"
if str(_ipynb) not in sys.path:
    sys.path.insert(0, str(_ipynb))

from view_augments.metric_review import (
    get_metric_paths,
    mip_biapy_gt_instance,
    plot_image_grid,
    plot_pred_gt_instance_mips,
)
# Out:
# /scratch/wmz2007/neuroinfo_fruitfly/ipynb
# /scratch/wmz2007/neuroinfo_fruitfly

# %% [markdown]
# ## Viewing Results

# %% [markdown]
# ### Segmentation Prediction

# %%
CONFIG = "biapy-channel-scale-zarr-seunet"
RUN = "1_w3443"

plot_image_grid(get_metric_paths('per_image_instances', CONFIG, RUN), mip_biapy_gt_instance, ncols=4, figsize_cell=(4, 4), font_siz=6)
plot_image_grid(get_metric_paths('per_image_post_processing', CONFIG, RUN), mip_biapy_gt_instance, ncols=4, figsize_cell=(4, 4), font_siz=6)
# Out:
# (<Figure size 1600x800 with 8 Axes>,
#  array([[<Axes: title={'center': 'GT instance MIP JRC_SS04989-20160318_24_A2'}>,
#          <Axes: title={'center': 'GT instance MIP R14A02-20180905_65_A6'}>,
#          <Axes: title={'center': 'GT instance MIP R54A09-20181019_64_H1'}>,
#          <Axes: title={'center': 'GT instance MIP VT011145-20171222_63_I1'}>],
#         [<Axes: title={'center': 'GT instance MIP VT027175-20171031_62_H3'}>,
#          <Axes: title={'center': 'GT instance MIP VT027175-20171031_62_H4'}>,
#          <Axes: title={'center': 'GT instance MIP VT050157-20171110_61_C1'}>,
#          <Axes: >]], dtype=object))

# %% [markdown]
# ### Compare with Ground Truth

# %%
GT_DIR = "fisbe/biapy-no-aug-zarr/test/label"

# %%
plot_pred_gt_instance_mips(
    CONFIG,
    RUN,
    gt_dir=GT_DIR,
    sub_folder="per_image_post_processing",
    figsize=(8, 4),
    font_siz=6,
)
# Out:
# [(<Figure size 800x400 with 2 Axes>,
#   array([<Axes: title={'center': 'GT (3 inst)'}>,
#          <Axes: title={'center': 'Pred (21 inst)'}>], dtype=object),
#   'JRC_SS04989-20160318_24_A2'),
#  (<Figure size 800x400 with 2 Axes>,
#   array([<Axes: title={'center': 'GT (7 inst)'}>,
#          <Axes: title={'center': 'Pred (18 inst)'}>], dtype=object),
#   'R14A02-20180905_65_A6'),
#  (<Figure size 800x400 with 2 Axes>,
#   array([<Axes: title={'center': 'GT (1 inst)'}>,
#          <Axes: title={'center': 'Pred (13 inst)'}>], dtype=object),
#   'R54A09-20181019_64_H1'),
#  (<Figure size 800x400 with 2 Axes>,
#   array([<Axes: title={'center': 'GT (9 inst)'}>,
#          <Axes: title={'center': 'Pred (10 inst)'}>], dtype=object),
#   'VT011145-20171222_63_I1'),
#  (<Figure size 800x400 with 2 Axes>,
#   array([<Axes: title={'center': 'GT (3 inst)'}>,
#          <Axes: title={'center': 'Pred (11 inst)'}>], dtype=object),
#   'VT027175-20171031_62_H3'),
#  (<Figure size 800x400 with 2 Axes>,
#   array([<Axes: title={'center': 'GT (6 inst)'}>,
#          <Axes: title={'center': 'Pred (19 inst)'}>], dtype=object),
#   'VT027175-20171031_62_H4'),
#  (<Figure size 800x400 with 2 Axes>,
#   array([<Axes: title={'center': 'GT (5 inst)'}>,
#          <Axes: title={'center': 'Pred (13 inst)'}>], dtype=object),
#   'VT050157-20171110_61_C1')]

# %%
# Pre-post-processing watershed output (uncomment to compare):
# plot_pred_gt_instance_mips(
#     CONFIG,
#     RUN,
#     gt_dir=GT_DIR,
#     sub_folder="per_image_instances",
#     figsize=(8, 4),
#     font_siz=6,
# )

# %%
# CONFIG = "biapy-channel-scale-zarr-seunet-FP"
# RUN = "1"

# plot_image_grid(get_metric_paths('per_image_instances', CONFIG, RUN), mip_biapy_gt_instance, ncols=4, figsize_cell=(4, 4), font_siz=6)
# plot_image_grid(get_metric_paths('per_image_post_processing', CONFIG, RUN), mip_biapy_gt_instance, ncols=4, figsize_cell=(4, 4), font_siz=6)
