# %%
import os
from pathlib import Path
import math

from scipy.special import expit

from tqdm.auto import tqdm

import navis
import navis.interfaces.neuprint as neu

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import seaborn as sns

import colorcet as cc

auth_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....2IB-bBQ1iE9PWe2zqD577hzIK2pAf6zCg5ztnbB_UnE"

client = neu.Client(
    "https://neuprint.janelia.org/",
    token=auth_token,
    # dataset="manc:v1.2.3",
    # dataset="hemibrain:v1.2.1",
    dataset="banc:v888",
)

# %%
# client = neu.Client(
#     "https://neuprint.janelia.org/",
#     token=auth_token,
# )

# %%
criteria = neu.NeuronCriteria(
    # rois=roi,
    # target=target,
    # instance=instance_regex,
    
    # bodyId = 720575941633779387, #banc 
    # bodyId = 331662717, # hemibrain
    
    # class_ = "motor neuron",
    # regex=True,
)

nl, roi_info = neu.fetch_neurons(
    criteria
)

# %%
nl = nl[nl.status == "Traced"]

nl["hemilineage"].value_counts().sort_index()
# Out:
# hemilineage
# 00A                  254
# 00B                   57
# 01A                  447
# 01B                  498
# 02A                  319
#                     ...
# WEDd1                210
# WEDd2                 76
# no_lineage            87
# primary               41
# putative_primary    3917
# Name: count, Length: 259, dtype: int64

# %%
nl[nl['bodyId'] == 331662717]
# Out:
#       bodyId  instance    type  pre  post  downstream  upstream  mito  \
# 0  331662717  KCab-s_R  KCab-s  224   630         715       630   120
#
#         size  status  cropped     statusLabel cellBodyFiber  somaRadius  \
# 0  287565290  Traced    False  Roughly traced         PDL02         301
#
#            somaLocation                                            roiInfo  \
# 0  [15338, 13953, 8784]  {'MB(R)': {'pre': 222, 'post': 626, 'downstrea...
#
#   notes                                          inputRois  \
# 0  None  [CA(R), MB(+ACA)(R), MB(R), PED(R), SIP(R), SN...
#
#                                           outputRois
# 0  [CA(R), MB(+ACA)(R), MB(R), PED(R), SIP(R), SN...

# %%
skels = neu.fetch_skeletons(nl, with_synapses=True)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
navis.plot3d(skels)
# Out:
# INFO  : Using "plotly" backend for 3D plotting. (navis)
